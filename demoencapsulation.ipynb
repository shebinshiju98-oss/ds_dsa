# %%
class Student:
    def __init__(self,id,name):
        self.__id=id
        self.__name=name
    def std_info(self):
         print(f"id:{self.id}name {self.name}")

# %%
s1=Student(1,"sheby")

# %%
s1.std_info()
# Out:
# id:1name sheby

# %%
s1.id=100

# %%
s1.std_info()
# Out:
# id:100name sheby

# %%
id.name="joel"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 id.name="joel"
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'name' and no __dict__ for setting new attributes

# %%
class Bank:
    name="SHEBIN"
    __balance=3000

# %%
b=Bank()

# %%
b.name
# Out:
# 'SHEBIN'

# %%
class Customer:
     id=0
     Name=None
     Address=None
    __email=None
    __phnum=None
# Out:
#   File <string>:5
#     __email=None
#                 ^
# IndentationError: unindent does not match any outer indentation level

# %%
class Cart:
     def __init__(self,name,code,price,Qty):
         self.name=name
         self.code=code
         self.price=price
         self.Qty=Qty
     def cart_info(self):
        total=self.price*self.Qty
        print(f"Name:{self.name} Code: {self.code} Price:{self.price} Qty:{self.Qty} Total:{total}")

# %%
cart=Cart("IPHONE",6468768,800000,3)

# %%
cart.cart_info()
# Out:
# Name:IPHONE Code: 6468768 Price:800000 Qty:3 Total:2400000
